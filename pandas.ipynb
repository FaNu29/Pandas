# %%
import pandas as pd
import numpy as np

# %%
dataset= {
    'cars' : ["BMW", "Volvo", "Ford"],
    'passings' : [3,5,3],
    'sell' : [5,3,4]
}

dp= pd.DataFrame(dataset)
print(dp)
# Out:
#     cars  passings  sell
# 0    BMW         3     5
# 1  Volvo         5     3
# 2   Ford         3     4

# %%
data=[1,3,5,3,2]
dp=pd.Series(data, index=["A", "B", "C", "D", "E"])
print(dp)
print(dp["A"])
# Out:
# A    1
# B    3
# C    5
# D    3
# E    2
# dtype: int64
# 1

# %%
df= pd.read_csv("data.csv")
print(df.to_string());
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
df=pd.read_json('data.json')
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.5
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
df.to_csv('example.csv')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 6.6 KB
# None

# %%
random_df=pd.DataFrame(np.random.rand(20,10))
random_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.915077  0.381125  0.105447  0.797853  0.868411  0.009253  0.351979
# 1  0.925504  0.106851  0.423879  0.811931  0.435794  0.044277  0.603280
# 2  0.669783  0.084261  0.632730  0.038627  0.186292  0.146777  0.974434
# 3  0.519098  0.246104  0.741780  0.152353  0.231590  0.254986  0.999269
# 4  0.823814  0.014973  0.213654  0.546032  0.287267  0.860816  0.688842
#
#           7         8         9
# 0  0.672601  0.168851  0.630591
# 1  0.280682  0.958104  0.245373
# 2  0.517435  0.611546  0.683062
# 3  0.718067  0.427084  0.451890
# 4  0.633389  0.381443  0.677124

# %%
print(df.head())
print(df.tail())
print(df.info())
print(df.isnull().sum())
print(df.value_counts('Duration'))
print(df.groupby('Duration').mean())
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
# <class 'pandas.core.frame.DataFrame'>
# Index: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 6.6 KB
# None
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64
# Duration
# ...

# %%
print(df.count())
print(df.std())
print(df.min())
print(df.max())
print(df.describe())
# Out:
# Duration    169
# Pulse       169
# Maxpulse    169
# Calories    164
# dtype: int64
# Duration     42.299949
# Pulse        14.510259
# Maxpulse     16.450434
# Calories    266.377134
# dtype: float64
# Duration     15.0
# Pulse        80.0
# Maxpulse    100.0
# Calories     50.3
# dtype: float64
# Duration     300.0
# Pulse        159.0
# Maxpulse     184.0
# Calories    1860.4
# dtype: float64
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.800000
# std     42.299949   14.510259   16.450434   266.377134
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
df['Duplicate'] = df.Pulse

# %%
df.head()
df.drop(index=0, axis=0)
# Out:
#      Duration  Pulse  Maxpulse  Calories  Duplicate
# 1          60    117       145     479.0        117
# 2          60    103       135     340.0        103
# 3          45    109       175     282.4        109
# 4          45    117       148     406.0        117
# 5          60    102       127     300.5        102
# ..        ...    ...       ...       ...        ...
# 164        60    105       140     290.8        105
# 165        60    110       145     300.4        110
# 166        60    115       145     310.2        115
# 167        75    120       150     320.4        120
# 168        75    125       150     330.4        125
#
# [168 rows x 5 columns]

# %%
df.drop(columns="Duplicate", axis=1)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
print(df.iloc[0])
print(df.iloc[:,3])
print(df.corr())
# Out:
# Duration      60.0
# Pulse        110.0
# Maxpulse     130.0
# Calories     409.1
# Duplicate    110.0
# Name: 0, dtype: float64
# 0      409.1
# 1      479.0
# 2      340.0
# 3      282.4
# 4      406.0
#        ...
# 164    290.8
# 165    300.4
# 166    310.2
# 167    320.4
# 168    330.4
# Name: Calories, Length: 169, dtype: float64
#            Duration     Pulse  Maxpulse  Calories  Duplicate
# Duration   1.000000 -0.155408  0.009403  0.922721  -0.155408
# Pulse     -0.155408  1.000000  0.786535  0.025120   1.000000
# Maxpulse   0.009403  0.786535  1.000000  0.203814   0.786535
# Calories   0.922721  0.025120  0.203814  1.000000   0.025120
# Duplicate -0.155408  1.000000  0.786535  0.025120   1.000000
